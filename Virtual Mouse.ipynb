# %%
pip install OpenCV
pip install MediaPipe

pip install PyAutoGUI
pip install protobuf
# Out:
# Requirement already satisfied: protobuf in c:\users\prati\anaconda3\lib\site-packages (3.20.3)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prati\anaconda3\lib\site-packages)

# %%
import cv2
import mediapipe as mp
import pyautogui
cap = cv2.VideoCapture(0)
hand_detector = mp.solutions.hands.Hands()
drawing_utils = mp.solutions.drawing_utils
screen_width, screen_height = pyautogui.size()
index_y = 0
while True:
    _, frame = cap.read()
    frame = cv2.flip(frame, 1)
    frame_height, frame_width, _ = frame.shape
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    output = hand_detector.process(rgb_frame)
    hands = output.multi_hand_landmarks
    if hands:
        for hand in hands:
            drawing_utils.draw_landmarks(frame, hand)
            landmarks = hand.landmark
            for id, landmark in enumerate(landmarks):
                x = int(landmark.x*frame_width)
                y = int(landmark.y*frame_height)
                if id == 8:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    index_x = screen_width/frame_width*x
                    index_y = screen_height/frame_height*y
                    pyautogui.moveTo(index_x, index_y)

                if id == 4:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    thumb_x = screen_width/frame_width*x
                    thumb_y = screen_height/frame_height*y
                    print('outside', abs(index_y - thumb_y))
                    if abs(index_y - thumb_y) < 20:
                        pyautogui.click()
                        #pyautogui.sleep(1)
                    elif abs(index_y - thumb_y) < 100:
                        pyautogui.moveTo(index_x, index_y)
    cv2.imshow('Hand Mouse', frame)
    cv2.waitKey(1)
# Out:
# outside 958.5
# outside 209.25
# outside 195.75
# outside 171.0
# outside 177.75
# outside 184.5
# outside 189.0
# outside 225.0
# outside 288.0
# outside 297.0
# outside 288.0
# outside 288.0
# outside 270.0
# outside 252.0
# outside 265.5
# outside 297.0
# outside 306.0
# outside 355.5
# outside 362.25
# outside 348.75
# outside 360.0
# outside 373.5
# outside 315.0
# outside 299.25
# outside 274.5
# outside 247.5
# outside 249.75
# outside 283.5
# outside 258.75
# outside 319.5
# outside 326.25
# outside 402.75
# outside 378.0
# outside 366.75
# outside 319.5
# outside 256.5
# outside 265.5
# outside 270.0
# outside 261.0
# outside 180.0
# outside 198.0
# outside 252.0
# outside 240.75
# outside 270.0
# outside 348.75
# outside 326.25
# outside 366.75
# outside 317.25
# outside 326.25
# outside 330.75
# outside 288.0
# outside 249.75
# outside 234.0
# outside 267.75
# outside 209.25
# outside 112.5
# outside 267.75
# outside 335.25
# outside 337.5
# outside 411.75
# outside 315.0
# outside 423.0
# outside 297.0
# outside 301.5
# outside 285.75
# outside 281.25
# outside 263.25
# outside 252.0
# outside 256.5
# outside 231.75
# outside 240.75
# outside 292.5
# outside 337.5
# outside 389.25
# outside 436.5
# outside 414.0
# outside 362.25
# outside 319.5
# outside 319.5
# outside 279.0
# outside 254.25
# outside 240.75
# outside 238.5
# outside 229.5
# outside 207.0
# outside 191.25
# outside 200.25
# outside 198.0
# outside 191.25
# outside 218.25
# outside 238.5
# outside 258.75
# outside 292.5
# outside 319.5
# outside 337.5
# outside 317.25
# outside 297.0
# outside 272.25
# outside 258.75
# outside 256.5
# outside 288.0
# outside 279.0
# outside 267.75
# outside 240.75
# outside 209.25
# outside 166.5
# outside 153.0
# outside 155.25
# outside 164.25
# outside 173.25
# outside 281.25
# outside 299.25
# outside 328.5
# outside 364.5
# outside 348.75
# outside 348.75
# outside 285.75
# outside 288.0
# outside 261.0
# outside 216.0
# outside 225.0
# outside 204.75
# outside 202.5
# outside 195.75
# outside 209.25
# outside 279.0
# outside 342.0
# outside 357.75
# outside 348.75
# outside 333.0
# outside 312.75
# outside 290.25
# outside 261.0
# outside 245.25
# outside 234.0
# outside 238.5
# outside 222.75
# outside 198.0
# outside 209.25
# outside 216.0
# outside 216.0
# outside 254.25
# outside 281.25
# outside 303.75
# outside 319.5
# outside 339.75
# outside 328.5
# outside 326.25
# outside 292.5
# outside 263.25
# outside 245.25
# outside 222.75
# outside 216.0
# outside 207.0
# outside 216.0
# outside 240.75
# outside 252.0
# outside 263.25
# outside 274.5
# outside 326.25
# outside 315.0
# outside 364.5
# outside 362.25
# outside 279.0
# outside 281.25
# outside 267.75
# outside 234.0
# outside 209.25
# outside 171.0
# outside 200.25
# outside 281.25
# outside 209.25
# outside 276.75
# outside 283.5
# outside 299.25
# outside 308.25
# outside 326.25
# outside 319.5
# outside 324.0
# outside 301.5
# outside 258.75
# outside 234.0
# outside 227.25
# outside 227.25
# outside 220.5
# outside 243.0
# outside 249.75
# outside 281.25
# outside 285.75
# outside 301.5
# outside 303.75
# outside 315.0
# outside 263.25
# outside 191.25
# outside 114.75
# outside 60.75
# outside 49.5
# outside 60.75
# outside 130.5
# outside 153.0
# outside 130.5
# outside 105.75
# outside 49.5
# outside 29.25
# outside 24.75
# outside 45.0
# outside 29.25
# outside 18.0
# outside 18.0
# outside 31.5
# outside 29.25
# outside 33.75
# outside 33.75
# outside 40.5
# outside 54.0
# outside 56.25
# outside 51.75
# outside 58.5
# outside 42.75
# outside 49.5
# outside 83.25
# outside 101.25
# outside 83.25
# outside 83.25
# outside 72.0
# outside 67.5
# outside 56.25
# outside 60.75
# outside 67.5
# outside 58.5
# outside 51.75
# outside 69.75
# outside 81.0
# outside 58.5
# outside 31.5
# outside 33.75
# outside 60.75
# outside 105.75
# outside 96.75
# outside 78.75
# outside 164.25
# outside 236.25
# outside 274.5
# outside 225.0
# outside 157.5
# outside 110.25
# outside 76.5
# outside 31.5
# outside 78.75
# outside 137.25
# outside 148.5
# outside 148.5
# outside 146.25
# outside 148.5
# outside 150.75
# outside 144.0
# outside 146.25
# outside 146.25
# outside 148.5
# outside 146.25
# outside 144.0
# outside 144.0
# outside 146.25
# outside 202.5
# outside 202.5
# outside 18.0
# outside 94.5
# outside 103.5
# outside 85.5
# outside 76.5
# outside 92.25
# outside 110.25
# outside 83.25
# outside 85.5
